# %% [markdown]
# # Importando libs e lendo o dataset

# %%
import pandas as pd

df = pd.read_csv("../data/prouni_2005_2019.csv")
df
# Out:
#          ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 0                       2005                    423
# 1                       2005                    423
# 2                       2005                    423
# 3                       2005                    423
# 4                       2005                    423
# ...                      ...                    ...
# 2692535                 2019                  18978
# 2692536                 2019                  18978
# 2692537                 2019                  18978
# 2692538                 2019                  18978
# 2692539                 2019                  18978
#
#                                             NOME_IES_BOLSA         TIPO_BOLSA  \
# 0        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 1        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 2        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# ...

# %%
df.isna().sum()
# Out:
# ANO_CONCESSAO_BOLSA                  0
# CODIGO_EMEC_IES_BOLSA                0
# NOME_IES_BOLSA                     489
# TIPO_BOLSA                           0
# MODALIDADE_ENSINO_BOLSA              0
# NOME_CURSO_BOLSA                  5654
# NOME_TURNO_CURSO_BOLSA               0
# CPF_BENEFICIARIO_BOLSA               0
# SEXO_BENEFICIARIO_BOLSA              0
# RACA_BENEFICIARIO_BOLSA              0
# DT_NASCIMENTO_BENEFICIARIO           0
# BENEFICIARIO_DEFICIENTE_FISICO       0
# REGIAO_BENEFICIARIO_BOLSA          402
# SIGLA_UF_BENEFICIARIO_BOLSA        402
# MUNICIPIO_BENEFICIARIO_BOLSA       402
# idade                                0
# dtype: int64

# %%
df.shape
# Out:
# (2692540, 16)

# %%
df_limpo = df.copy()
df_limpo = df_limpo.dropna()
df_limpo
# Out:
#          ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 0                       2005                    423
# 1                       2005                    423
# 2                       2005                    423
# 3                       2005                    423
# 4                       2005                    423
# ...                      ...                    ...
# 2692535                 2019                  18978
# 2692536                 2019                  18978
# 2692537                 2019                  18978
# 2692538                 2019                  18978
# 2692539                 2019                  18978
#
#                                             NOME_IES_BOLSA         TIPO_BOLSA  \
# 0        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 1        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 2        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# ...

# %%
df_limpo.isna().sum()
# Out:
# ANO_CONCESSAO_BOLSA               0
# CODIGO_EMEC_IES_BOLSA             0
# NOME_IES_BOLSA                    0
# TIPO_BOLSA                        0
# MODALIDADE_ENSINO_BOLSA           0
# NOME_CURSO_BOLSA                  0
# NOME_TURNO_CURSO_BOLSA            0
# CPF_BENEFICIARIO_BOLSA            0
# SEXO_BENEFICIARIO_BOLSA           0
# RACA_BENEFICIARIO_BOLSA           0
# DT_NASCIMENTO_BENEFICIARIO        0
# BENEFICIARIO_DEFICIENTE_FISICO    0
# REGIAO_BENEFICIARIO_BOLSA         0
# SIGLA_UF_BENEFICIARIO_BOLSA       0
# MUNICIPIO_BENEFICIARIO_BOLSA      0
# idade                             0
# dtype: int64

# %%
lista_colunas = list(df.columns)
lista_colunas
# Out:
# ['ANO_CONCESSAO_BOLSA',
#  'CODIGO_EMEC_IES_BOLSA',
#  'NOME_IES_BOLSA',
#  'TIPO_BOLSA',
#  'MODALIDADE_ENSINO_BOLSA',
#  'NOME_CURSO_BOLSA',
#  'NOME_TURNO_CURSO_BOLSA',
#  'CPF_BENEFICIARIO_BOLSA',
#  'SEXO_BENEFICIARIO_BOLSA',
#  'RACA_BENEFICIARIO_BOLSA',
#  'DT_NASCIMENTO_BENEFICIARIO',
#  'BENEFICIARIO_DEFICIENTE_FISICO',
#  'REGIAO_BENEFICIARIO_BOLSA',
#  'SIGLA_UF_BENEFICIARIO_BOLSA',
#  'MUNICIPIO_BENEFICIARIO_BOLSA',
#  'idade']

# %%
lista_apagar = ['CODIGO_EMEC_IES_BOLSA']
df_limpo = df_limpo.drop(['CODIGO_EMEC_IES_BOLSA', 'CPF_BENEFICIARIO_BOLSA','DT_NASCIMENTO_BENEFICIARIO'], axis=1)
df_limpo
# Out:
#          ANO_CONCESSAO_BOLSA  \
# 0                       2005
# 1                       2005
# 2                       2005
# 3                       2005
# 4                       2005
# ...                      ...
# 2692535                 2019
# 2692536                 2019
# 2692537                 2019
# 2692538                 2019
# 2692539                 2019
#
#                                             NOME_IES_BOLSA         TIPO_BOLSA  \
# 0        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 1        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 2        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 3        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 4        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# ...                                                    ...                ...
# ...

# %%
lista_renomear = ['ANO DE CONCESSÃO',
 'IES',
 'TIPO',
 'MODALIDADE DE ENSINO',
 'CURSO',
 'TURNO', 
 'SEXO',
 'RAÇA',
 'DEFICIENTE FÍSICO',
 'REGIÃO',
 'UF',
 'MUNICÍPIO',
 'IDADE']
lista_renomear
# Out:
# ['ANO DE CONCESSÃO',
#  'IES',
#  'TIPO',
#  'MODALIDADE DE ENSINO',
#  'CURSO',
#  'TURNO',
#  'SEXO',
#  'RAÇA',
#  'DEFICIENTE FÍSICO',
#  'REGIÃO',
#  'UF',
#  'MUNICÍPIO',
#  'IDADE']

# %%
df_limpo.columns = lista_renomear
df_limpo
# Out:
#          ANO DE CONCESSÃO                                                IES  \
# 0                    2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# 1                    2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# 2                    2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# 3                    2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# 4                    2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# ...                   ...                                                ...
# 2692535              2019               FACULDADE REBOUAAS DE CAMPINA GRANDE
# 2692536              2019               FACULDADE REBOUAAS DE CAMPINA GRANDE
# 2692537              2019               FACULDADE REBOUAAS DE CAMPINA GRANDE
# 2692538              2019               FACULDADE REBOUAAS DE CAMPINA GRANDE
# 2692539              2019               FACULDADE REBOUAAS DE CAMPINA GRANDE
#
# ...

# %%
# df_limpo_ml = df_limpo.copy()

# %%
lista_unicos = list(df_limpo["TIPO"].unique())
lista_unicos
# Out:
# ['BOLSA PARCIAL 50%', 'BOLSA INTEGRAL', 'BOLSA COMPLEMENTAR 25%']

# %%
# df_limpo_ml['Tipo'] = df_limpo_ml['Tipo'].replace({'BOLSA INTEGRAL': 0,'BOLSA PARCIAL 50%': 1,'BOLSA COMPLEMENTAR 25%': 2})
# df_limpo_ml['Modalidade de ensino'] = df_limpo_ml['Modalidade de ensino'].replace({'INTEGRAL': 0,'EAD':1})
# df_limpo_ml['Turno'] = df_limpo_ml['Turno'].replace({'Integral': 0,'Matutino': 1, 'Vespertino': 2, 'Noturno': 3, 'A Distancia': 4})
# df_limpo_ml['Deficiente físico'] = df_limpo_ml['Deficiente físico'].replace({'nao': 0,'sim': 1})
# df_limpo_ml['Raça'] = df_limpo_ml['Raça'].replace({'Branca': 0, 'Parda': 1, 'Amarela': 2, 'Preta': 3, 'Indigena': 4,'Nao Informada': 5})

# %%
df_limpo = df_limpo[df_limpo['IDADE'] <= 100]

# %%
df_limpo.to_csv('../data/prouni_2005_2019_processed.csv', index=False)

# %%
df_limpo.head()
# Out:
#    ANO DE CONCESSÃO                                                IES  \
# 0              2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# 1              2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# 2              2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# 3              2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# 4              2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
#
#                 TIPO MODALIDADE DE ENSINO                  CURSO     TURNO  \
# 0  BOLSA PARCIAL 50%           PRESENCIAL             Enfermagem  Integral
# 1  BOLSA PARCIAL 50%           PRESENCIAL         Servico Social   Noturno
# 2  BOLSA PARCIAL 50%           PRESENCIAL         Servico Social   Noturno
# 3  BOLSA PARCIAL 50%           PRESENCIAL  Ciencia Da Computacao   Noturno
# 4  BOLSA PARCIAL 50%           PRESENCIAL  Ciencia Da Computacao   Noturno
#
#   SEXO     RAÇA DEFICIENTE FÍSICO REGIÃO  UF             MUNICÍPIO  IDADE
# ...
